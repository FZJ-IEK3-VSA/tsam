# %% [markdown]
# # tsam - Representation
# Example usage of the time series aggregation module (tsam)
# Date: 29.04.2019
#
# Author: Maximilian Hoffmann

# %% [markdown]
# Import pandas and the relevant time series aggregation class

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd

# Configure Plotly for sphinx/nbsphinx output
import plotly.io as pio

import tsam
from tsam import ClusterConfig

pio.renderers.default = "notebook"

# %% [markdown]
# ### Input data

# %% [markdown]
# Read in time series from testdata.csv with pandas

# %%
raw = pd.read_csv("testdata.csv", index_col=0)

# %% [markdown]
# Create a plot function for the temperature for a visual comparison of the time series

# %%
# Use tsam's built-in plotting with plotly
# tsam.plot.heatmap(data, column, period_hours) creates interactive heatmaps

# %% [markdown]
# ### Hierarchical aggregation with medoid representation at hourly resolution

# %% [markdown]
# Initialize an aggregation class object with hierarchical as method for eight typical days

# %%
result_medoid = tsam.aggregate(
    raw,
    n_periods=8,
    period_hours=24,
    cluster=ClusterConfig(method="hierarchical", representation="medoid"),
)

# %% [markdown]
# Create the typical periods

# %%
typical_periods_medoid = result_medoid.typical_periods

# %% [markdown]
# Predict original data

# %%
reconstructed_medoid = result_medoid.reconstruct()

# %% [markdown]
# Get accuracy indicators

# %%
result_medoid.accuracy

# %% [markdown]
# ### Hierarchical aggregation with maxoid representation at hourly resolution

# %%
result_maxoid = tsam.aggregate(
    raw,
    n_periods=8,
    period_hours=24,
    cluster=ClusterConfig(method="hierarchical", representation="maxoid"),
    rescale=False,
)

# %% [markdown]
# Create the typical periods

# %%
typical_periods_maxoid = result_maxoid.typical_periods

# %% [markdown]
# Predict original data

# %%
reconstructed_maxoid = result_maxoid.reconstruct()

# %% [markdown]
# Get accuracy indicators

# %%
result_maxoid.accuracy

# %% [markdown]
# ### Hierarchical aggregation with mean representation and 10 typical days at hourly resolution

# %%
result_mean = tsam.aggregate(
    raw,
    n_periods=20,
    period_hours=24,
    cluster=ClusterConfig(method="hierarchical", representation="mean"),
)

# %% [markdown]
# Create the typical periods

# %%
typical_periods_mean = result_mean.typical_periods

# %% [markdown]
# Predict original data

# %%
reconstructed_mean = result_mean.reconstruct()

# %% [markdown]
# Get accuracy indicators

# %%
result_mean.accuracy

# %% [markdown]
# ### Hierarchical aggregation with minmax representation and 10 typical days at hourly resolution

# %%
result_minmax = tsam.aggregate(
    raw,
    n_periods=20,
    period_hours=24,
    cluster=ClusterConfig(method="hierarchical", representation="minmax_mean"),
    rescale=False,
)

# %% [markdown]
# Create the typical periods

# %%
typical_periods_minmax = result_minmax.typical_periods

# %% [markdown]
# Predict original data

# %%
reconstructed_minmax = result_minmax.reconstruct()

# %% [markdown]
# Get accuracy indicators

# %%
result_minmax.accuracy

# %% [markdown]
# ### Hierarchical aggregation with duration representation and 10 typical days at hourly resolution

# %%
result_duration = tsam.aggregate(
    raw,
    n_periods=20,
    period_hours=24,
    cluster=ClusterConfig(method="hierarchical", representation="duration"),
    rescale=False,
)

# %% [markdown]
# Create the typical periods

# %%
typical_periods_duration = result_duration.typical_periods

# %% [markdown]
# Predict original data

# %%
reconstructed_duration = result_duration.reconstruct()

# %% [markdown]
# Get accuracy indicators

# %%
result_duration.accuracy

# %% [markdown]
# ### Comparison of the aggregations
# It was shown for the temperature, but both times all four time series have been aggregated. Therefore, we compare here also the duration curves  of the electrical load for the original time series, the aggregation with k-mean, and the hierarchical aggregation including peak periods.

# %%
# Compare duration curves using built-in function
tsam.plot.compare_results(
    {
        "Original": raw,
        "Medoid": reconstructed_medoid,
        "Maxoid": reconstructed_maxoid,
        "Mean": reconstructed_mean,
        "Minmax": reconstructed_minmax,
    },
    column="Load",
    plot_type="duration_curve",
)

# %%
param = "GHI"

# %%
# Original data heatmap
tsam.plot.heatmap(raw, column=param, period_hours=24, title=f"Original {param}")

# %%
# Medoid representation heatmap
tsam.plot.heatmap(
    reconstructed_medoid, column=param, period_hours=24, title=f"Medoid {param}"
)

# %%
# Maxoid representation heatmap
tsam.plot.heatmap(
    reconstructed_maxoid, column=param, period_hours=24, title=f"Maxoid {param}"
)

# %%
# Mean representation heatmap
tsam.plot.heatmap(
    reconstructed_mean, column=param, period_hours=24, title=f"Mean {param}"
)

# %%
# Minmax representation heatmap
tsam.plot.heatmap(
    reconstructed_minmax, column=param, period_hours=24, title=f"Minmax {param}"
)

# %%
# Duration representation heatmap
tsam.plot.heatmap(
    reconstructed_duration, column=param, period_hours=24, title=f"Duration {param}"
)

# %%
# Time slice comparison using built-in function
tsam.plot.compare_results(
    {
        "Original": raw,
        "Medoid": reconstructed_medoid,
        "Maxoid": reconstructed_maxoid,
        "Mean": reconstructed_mean,
        "Minmax": reconstructed_minmax,
    },
    column="Load",
    plot_type="time_slice",
    start="20100210",
    end="20100218",
)

# %% [markdown]
# ### Validation

# %% [markdown]
# Check that the means of the original time series and the predicted ones are the same.

# %%
raw.mean()

# %%
reconstructed_medoid.mean()

# %%
reconstructed_maxoid.mean()

# %%
reconstructed_mean.mean()

# %%
reconstructed_minmax.mean()

# %%
reconstructed_duration.mean()
