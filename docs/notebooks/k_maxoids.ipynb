# %% [markdown]
# # K-Maxoids Clustering
# Example comparing k-means and k-maxoids clustering methods.
#
# K-maxoids automatically preserves extreme periods by selecting points closest to the convex hull.
#
# Author: Maximilian Hoffmann

# %% [markdown]
# Import pandas and the relevant time series aggregation class

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

import pandas as pd
import plotly.express as px
import plotly.io as pio

import tsam
from tsam import ClusterConfig

pio.renderers.default = "notebook_connected"

# Ensure results directory exists
RESULTS_DIR = Path("results")
RESULTS_DIR.mkdir(exist_ok=True)
import warnings

# Added to every example notebook: silence the v3 column-order
# FutureWarning in the rendered docs (tsam v4 returns result columns in
# input order; see migration guide).
warnings.filterwarnings(
    "ignore", category=FutureWarning, message=".*sorted alphabetically.*"
)

# %% [markdown]
# ### Input data

# %% [markdown]
# Read in time series from testdata.csv with pandas

# %%
raw = pd.read_csv("testdata.csv", index_col=0)

# %% [markdown]
# Show a slice of the dataset

# %%
raw.head()
# Out:
#                      GHI    T  Wind        Load
# 2009-12-31 23:30:00    0 -2.1   7.1  375.478394
# 2010-01-01 00:30:00    0 -2.8   8.6  364.541326
# 2010-01-01 01:30:00    0 -3.3   9.7  357.416844
# 2010-01-01 02:30:00    0 -3.2   9.8  350.191306
# 2010-01-01 03:30:00    0 -3.2   9.4  345.161449

# %% [markdown]
# Show the shape of the raw input data: 4 types of timeseries (GHI, Temperature, Wind and Load) for every hour in a year

# %%
raw.shape
# Out:
# (8760, 4)

# %% [markdown]
# Create a plot function for the temperature for a visual comparison of the time series

# %%
# Use tsam.unstack_to_periods() with plotly for heatmap visualization
# px.imshow(unstacked["column"].values.T) creates interactive heatmaps

# %% [markdown]
# Plot an example series - in this case the temperature

# %%
# Original temperature heatmap
unstacked = tsam.unstack_to_periods(raw, period_duration=24)
px.imshow(
    unstacked["T"].values.T,
    labels={"x": "Day", "y": "Hour", "color": "Temperature"},
    title="Original Temperature",
    aspect="auto",
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="9bf63c5e-2094-47c2-9c96-f6d5bb36b2d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9bf63c5e-2094-47c2-9c96-f6d5bb36b2d1")) {                    Plotly.newPlot(                        "9bf63c5e-2094-47c2-9c96-f6d5bb36b2d1",                        [{"coloraxis":"coloraxis","name":"0","z":{"dtype":"f8","bdata":"zczMzMzMAMAzMzMzMzPTP83MzMzMzBJAMzMzMzMz0z\u002fNzMzMzMwMQGZmZmZmZh5AzczMzMzMCEDNzMzMzMz8PzMzMzMzM9M\u002fzczMzMzM7L8zMzMzMzPTP2ZmZmZmZg7AAAAAAAAABMBmZmZmZmYQwJqZmZmZmRfAZmZmZmZmFMAAAAAAAAAcwAAAAAAAAAzAZmZmZmZmBsAzMzMzMzMDwDMzMzMzMwfAMzMzMzMzB8AAAAAAAAD4P2ZmZmZmZhRAzczMzMzMBEAAAAAAAAAAQM3MzMzMzPS\u002fZmZmZmZmGMAzMzMzMzPTPzMzMzMzMxlAMzMzMzMzF0CamZm
    n_clusters=8,
    period_duration=24,
    cluster=ClusterConfig(method="kmeans"),
)

# %% [markdown]
# Create the typical periods

# %%
cluster_representatives = result.cluster_representatives

# %% [markdown]
# Show shape of typical periods: 4 types of timeseries for 8*24 hours

# %%
cluster_representatives.shape
# Out:
# (192, 4)

# %% [markdown]
# Save typical periods to .csv file

# %%
cluster_representatives.to_csv(RESULTS_DIR / "testperiods_kmeans.csv")

# %% [markdown]
# Repredict the original time series based on the typical periods

# %%
reconstructed = result.reconstructed

# %% [markdown]
# Plot the repredicted data

# %%
# K-means predicted temperature heatmap
unstacked_kmeans = tsam.unstack_to_periods(reconstructed, period_duration=24)
px.imshow(
    unstacked_kmeans["T"].values.T,
    labels={"x": "Day", "y": "Hour", "color": "Temperature"},
    title="K-means Predicted Temperature",
    aspect="auto",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="2cc7b85a-54f7-41cf-9de9-ec68ee2c57a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2cc7b85a-54f7-41cf-9de9-ec68ee2c57a9")) {                    Plotly.newPlot(                        "2cc7b85a-54f7-41cf-9de9-ec68ee2c57a9",                        [{"coloraxis":"coloraxis","name":"0","z":{"dtype":"f8","bdata":"\u002fb6Jk1yZKAsAhSZIkSZIIQCFJkiRJkghAIUmSJEmSCEAhSZIkSZIIQCFJkiRJkghARrAFW7AF0z9vomTXJkoCwEawBVuwBdM\u002fb6Jk1yZKAsBvomTXJkoCwG+iZNcmSgLAo8hAen+uBUA1MzMzMzMVQKPIQHp\u002frgVAIUmSJEmSCEBvomTXJkoCwG+iZNcmSgLAb6Jk1yZKAsBGsAVbsAXTP0awBVuwBdM\u002fb6Jk1yZKAsAhSZIkSZIIQG+iZNcmSgLAb6Jk1yZKAsAhSZIkSZIIQKPIQHp\u002frgVARrAFW7AF0z8hSZIkSZIIQKPIQHp\u002frgVAo8hAen+uBUAhSZIkSZIIQCFJkiRJkghANTMzMzMzFUA1MzMzMzMVQCFJkiRJkghAIUmSJEmSCEBGsAVbsAXTPyFJkiRJkghAIUmSJEmSCEBGsAVbsAXTP0awBVuwBdM\u002fIUmSJEmSCECjyEB6f64FQKPIQHp\u002frgVAIUmSJEmSCEAhSZIkSZIIQEawBVuwBdM\u002fRrAFW7AF0z+jyEB6f64FQKPIQHp\u002frgVAo8hAen+uBUCjyEB6f64FQKPIQHp\u002frgVARrAFW7AF0z9GsAVbsAXTP6PIQHp\u002frgVAIUmSJEmSCECjyEB6f64FQMLaN6x9oyRAXeiFXugFJUBd6IVe6AUlQF3ohV7oBSVAXeiFXugFJUDC2jesfaMkQMLaN6x9oyRAIUmSJEmSCEAhSZIkSZIIQEawBVuwBdM\\...\\u002frgVAo8hAen+uBUAhSZIkSZIIQCFJkiRJkghANTMzMzMzFUA1MzMzMzMVQCFJkiRJkghAIUmSJEmSCEAhSZIkSZIIQCFJkiRJkghAIUmSJEmSCEA1MzMzMzMVQEawBVuwBdM\u002fo8hAen+uBUDC2jesfaMkQKPIQHp\u002frgVA
# Initialize a time series aggregation based on k-maxoids, which automatically searches for points closest to the convex hull.

# %%
result_maxoids = tsam.aggregate(
    raw,
    n_clusters=8,
    period_duration=24,
    cluster=ClusterConfig(method="kmaxoids"),
    preserve_column_means=False,
)

# %% [markdown]
# Create the typical periods

# %%
cluster_representatives_maxoids = result_maxoids.cluster_representatives

# %% [markdown]
# The aggregation can also be evaluated by indicators

# %%
result_maxoids.accuracy
# Out:
# AccuracyMetrics(
#   rmse=0.1704 (weighted),
#   mae=0.1187 (weighted),
#   rmse_duration=0.0930 (weighted)
# )

# %% [markdown]
# Repredict the original time series based on the typical periods

# %%
reconstructed_maxoids = result_maxoids.reconstructed

# %% [markdown]
# Plot repredicted data

# %%
# K-maxoids predicted temperature heatmap
unstacked_maxoids = tsam.unstack_to_periods(reconstructed_maxoids, period_duration=24)
px.imshow(
    unstacked_maxoids["T"].values.T,
    labels={"x": "Day", "y": "Hour", "color": "Temperature"},
    title="K-maxoids Predicted Temperature",
    aspect="auto",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="4e1bb626-acd2-4757-9436-43de3529241e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4e1bb626-acd2-4757-9436-43de3529241e")) {                    Plotly.newPlot(                        "4e1bb626-acd2-4757-9436-43de3529241e",                        [{"coloraxis":"coloraxis","name":"0","z":{"dtype":"f8","bdata":"AAAAAAAAIUBoZmZmZmYmQDEzMzMzMwfAMzMzMzMz0z8AAAAAAAAhQAAAAAAAACFAMTMzMzMzB8AxMzMzMzMHwDEzMzMzMwfAMTMzMzMzB8AxMzMzMzMHwDEzMzMzMwfAAAAAAAAAFMAxMzMzMzMHwDEzMzMzMwfAMTMzMzMzB8AxMzMzMzMHwDEzMzMzMwfAMTMzMzMzB8AAAAAAAAAUwDEzMzMzMwfAMTMzMzMzB8AzMzMzMzPTPzMzMzMzM9M\u002fMTMzMzMzB8AxMzMzMzMHwAAAAAAAABTAMTMzMzMzB8AzMzMzMzPTPzMzMzMzM9M\\...\...\\u002fMTMzMzMzB8AAAAAAAAAlQGZmZmZmZhTAMTMzMzMzB8ABAAAAAAAnQDEzMzMzMwfAMTMzMzMzB8AxMzMzMzMHwDEzMzMzMwfAAAAAAAAAJUAxMzMzMzMHwAMAAAAAAOA\\...\...\u002fk5mZmZmZ6T8AAAAAAAAIwAAAAAAAAAjAAAAAAAAAFMAAAAAAAAAIwJOZmZmZmek\u002fk5mZmZmZ6T+TmZmZmZnpPwAAAAAAAAjAAAAAAAAAJUAAAAAAAAAUwAAAAAAAAAjAzszMzMzMJUAAAAAAAAAIwAAAAAAAAAjAAAAAAAAACMAAAAAAAAAIwAAAAAAAACVAAAAAAAAACMCTmZmZmZnpPwAAAAAAAAjAAAAAAAAACMAAAAAAAAAIwAAAAAAAABTAAAAAAAAAFMAAAAAAAAAIwJOZmZmZmek\u002fAAAAAAAACMAAAAAAAAAIwJOZmZmZmek\...\...\u002fzszMzMzMCMDOzMzMzMwIwM3MzMzMzBTAzszMzMzMCMDMzMzMzMzsP8zMzMzMzOw\u002fzMzMzMzM7D\u002fOzMzMzMwIwDUzMzMzMyVAzczMzMzMFMDOzMzMzMwIwDUzMzMzMyVAzszMzMzMCMDOzMzMzMwIwM7MzMzMzAjAzszMzMzMCMA1MzMzMzMlQM7MzMzMzAjAzMzMzMzM7D\u002fOzMzMzMwIwM7MzMzMzAjAzszMzMzMCMDNzMzMzMwUwM3MzMzMzBTAzszMzMzMCMDMzMzMzMzsP87MzMzMzAjAzszMzMzMCMDMzMzMzMzsP87MzMzMzAjAzczMzMzMFMDOzMzMzMwIwM7MzMzMzAjAzszMzMzMCMDOzMzMzMwIwMzMzMzMzOw\u002fNTMzMzMzJUBlZmZmZmYgQDUzMzMzMyVAzszMzMzMCMDNzMzMzMwUwM7MzMzMzAjAzszMzMzMCMDNzMzMzMwUwM3MzMzMzBTAzMzMzMzM7D\...\...\u002fOzMzMzMwIwDUzMzMzMyVAzczMzMzMFMDOzMzMzMwIwM7MzMzMzAjAzszMzMzMCMDOzMzMzMwIwM3MzMzMzBTAzczMzMzMFMDNzMzMzMwUwM3MzMzMzBTAzczMzMzMFMDNzMzMzMwUwM3MzMzMzBTAZWZmZmZmIEBlZmZmZmYgQGVmZmZmZiBAZWZmZmZmIEDNzMzMzMwUwJqZmZmZmSBAzczMzMzMJECamZmZmZkJwAMAAAAAAPA\\u002fmpmZmZmZCcDNzMzMzMwkQDMzMzMzMxXAmpmZmZmZCcAAAAAAAAAlQJqZmZmZmQnAmpmZmZmZCcCamZmZmZkJwJqZmZmZmQnAzczMzMzMJECamZmZmZkJwAMAAAAAAPA\\...\u002fNzMzMzMwkQAMAAAAAAPA\...\u002fY2ZmZmZm9j9mZmZmZmYKwGZmZmZmZgrAZ2ZmZmZmFsBmZmZmZm ...

# %% [markdown]
# Here bigger biggest values and lower lowest values can be observed compared to k-means clustering.

# %% [markdown]
# ### Comparison of the aggregations
# It was shown for the temperature, but both times all four time series have been aggregated. Therefore, we compare here also the duration curves  of the electrical load for the original time series, the aggregation with k-mean, and the k-maxoids aggregation.

# %%
# Duration curve comparison using plotly express
comparison_data = {
    "Original": raw,
    "8 typ days (Centroids)": reconstructed,
    "8 typ days (Maxoids)": reconstructed_maxoids,
}

frames = []
for name, df in comparison_data.items():
    sorted_vals = df["Load"].sort_values(ascending=False).reset_index(drop=True)
    frames.append(
        pd.DataFrame(
            {"Hour": range(len(sorted_vals)), "Load": sorted_vals, "Method": name}
        )
    )
long_df = pd.concat(frames, ignore_index=True)

px.line(
    long_df,
    x="Hour",
    y="Load",
    color="Method",
    title="Duration Curve Comparison - Load",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="aed4dbb9-9c3a-45a0-a6ff-60da24a521eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("aed4dbb9-9c3a-45a0-a6ff-60da24a521eb")) {                    Plotly.newPlot(                        "aed4dbb9-9c3a-45a0-a6ff-60da24a521eb",                        [{"hovertemplate":"Method=Original\u003cbr\u003eHour=%{x}\u003cbr\u003eLoad=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Original","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Original","showlegend":true,"x":{"dtype":"i2","bdata":"\\u002fAD9AP4A\u002fwAAAQEBAgEDAQQBBQEGAQcBCAEJAQoBCwEMAQ0BDgEPARABEQESARMBFAEVARYBFwEYARkBGgEbARwBHQEeAR8BIAEhASIBIwEkASUBJgEnASgBKQEqASsBLAEtAS4BLwEwATEBMgEzATQBNQE2ATcBOAE5AToBOwE8AT0BPgE\...\u002fgH\...\u002fAsACwQLCAsMCxALFAsYCxwLIAskCygLLAswCzQLOAs8C0ALRAtIC0wLUAtUC1gLXAtgC2QLaAtsC3ALdAt4C3wLgAuEC4gLjAuQC5QLmAucC6ALpAuoC6wLsAu0C7gLvAvAC8QLyAvMC9AL1AvYC9wL4AvkC+gL7AvwC\\\u002fID8wP0A\u002fUD9gP3A\u002fgD+QP6A\u002fsD\u002fAP9A\u002f4D\u002fwMABAEEAgQDBAQEBQQGBAcECAQJBAoECwQMBA0EDgQPBBAEEQQSBBMEFAQVBBYEFwQYBBkEGgQbBBwEHQQeBB8EIAQhBCIEIwQkBCUEJgQnBCgEKQQqBCsELAQtBC4ELwQwBDEEMgQzBDQENQQ2BDcEOAQ5BDoEOwQ8BD0EPgQ\...\u002fgT\...\u002fBcAFwQXCBcMFxAXFBcYFxwXIBckFygXLBcwFzQXOBc8F0AXRBdIF0wXUBdUF1gXXBdgF2QXaBdsF3AXdBd4F3wXgBeEF4gXjBeQF5QXmBecF6AXpBeoF6wXsBe0F7gXvBfAF8QXyBfMF9AX1BfYF9wX4BfkF+gX7BfwF\\\u002fAb9Bv4G\u002fwYABwEHAgcDBwQHBQcGBwcHCAcJBwoHCwcMBw0HDgcPBxAHEQcSBxMHFAcVBxYHFwcYBxkHGgcbBxwHHQceBx8HIAchByIHIwckByUHJgcnBygHKQcqBysHLActBy4HLwcwBzEHMgczBzQHNQc2BzcHOAc5BzoHOwc8Bz0HPgc\...\u002fEH8gfzB\u002fQH9Qf2B\u002fcH+Af5B\u002foH+wf8B\ ...

# %% [markdown]
# Or as unsorted time series for an example week

# %%
# Time slice comparison using plotly express
frames = []
for name, df in comparison_data.items():
    sliced = df.loc["20100210":"20100218", ["Load"]].copy()
    sliced["Method"] = name
    frames.append(sliced)
long_df = pd.concat(frames).reset_index(names="Time")

px.line(
    long_df,
    x="Time",
    y="Load",
    color="Method",
    title="Time Slice Comparison - Load (Feb 10-18)",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="94d07e29-18a2-47d9-a66e-309ebbf29cac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("94d07e29-18a2-47d9-a66e-309ebbf29cac")) {                    Plotly.newPlot(                        "94d07e29-18a2-47d9-a66e-309ebbf29cac",                        [],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scattermap":[{"type":"scattermap","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scattermapbox":[{"type":"scattermapbox","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterternary":[{"type":"scatterternary","marker":{"colorbar":{"out ...
