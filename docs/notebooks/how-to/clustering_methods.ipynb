# %% [markdown]
# # Clustering methods
#
# Aggregation has two halves: **grouping** similar periods, then **representing**
# each group with one profile. This page is about the first half — the clustering
# method, set with `ClusterConfig(method=...)`. (For the second, see
# [Representations](representations.ipynb).)
#
# tsam offers six methods:
#
# | method | how it groups | notes |
# |--------|---------------|-------|
# | `hierarchical` | merges the closest periods step by step | the **default** — robust, deterministic |
# | `kmeans` | minimises distance to cluster centroids | fast, often most accurate |
# | `kmedoids` | like k-means but centers are **real** periods | exact (MILP), slower |
# | `kmaxoids` | centers pushed toward extremes | preserves spread, not the average |
# | `averaging` | splits the timeline into equal chunks | simplest baseline, ignores similarity |
# | `contiguous` | only merges temporally adjacent periods | keeps calendar order |

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

import tsam

pio.renderers.default = "notebook_connected"

raw = pd.read_csv("../testdata.csv", index_col=0, parse_dates=True)
data = raw.loc["2010-01-01":"2010-02-11"]  # six weeks of hourly data

# %% [markdown]
# ## Accuracy and speed
#
# Run all six at the same size and compare. The right choice trades accuracy
# against runtime (which matters once you have thousands of periods):

# %%
from tsam import ClusterConfig

methods = ["hierarchical", "kmeans", "kmedoids", "kmaxoids", "averaging", "contiguous"]
rows = {}
for m in methods:
    r = tsam.aggregate(
        data, n_clusters=6, period_duration="1D", cluster=ClusterConfig(method=m)
    )
    rows[m] = {
        "mean RMSE": round(float(r.accuracy.rmse.mean()), 4),
        "clustering time (s)": round(r.clustering_duration, 3),
    }
pd.DataFrame(rows).T.sort_values("mean RMSE")
# Out:
# C:\Users\j.belina\AppData\Local\miniforge3\envs\tsam_improve_reworked_notebooks\Lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\j.belina\AppData\Local\miniforge3\envs\tsam_improve_reworked_notebooks\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#               mean RMSE  clustering time (s)
# kmeans           0.0971               12.936
# hierarchical     0.1152                0.149
# kmedoids         0.1175                4.946
# averaging        0.1323                0.000
# contiguous       0.1415                0.005
# kmaxoids         0.1568                0.773

# %% [markdown]
# ## How the grouping plays out
#
# Same data, same number of clusters — but the methods assign days to groups
# differently, so the reconstructed series differ. Over one week: `kmeans` and
# `hierarchical` track the original closely, while `averaging` (blind to
# similarity) is visibly coarser.

# %%
week = slice("2010-01-11", "2010-01-17")
frames = []
for m in ["hierarchical", "kmeans", "kmedoids", "averaging"]:
    r = tsam.aggregate(
        data, n_clusters=6, period_duration="1D", cluster=ClusterConfig(method=m)
    )
    s = r.reconstructed.loc[week, "Load"]
    frames.append(pd.DataFrame({"time": s.index, "Load": s.values, "method": m}))
orig = data.loc[week, "Load"]
frames.append(
    pd.DataFrame({"time": orig.index, "Load": orig.values, "method": "original"})
)
px.line(
    pd.concat(frames),
    x="time",
    y="Load",
    color="method",
    title="One week reconstructed, by clustering method",
)
# Out:
# C:\Users\j.belina\AppData\Local\miniforge3\envs\tsam_improve_reworked_notebooks\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.4.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="d7669942-ce7c-40c0-a2da-714e0920e48a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d7669942-ce7c-40c0-a2da-714e0920e48a")) {                    Plotly.newPlot(                        "d7669942-ce7c-40c0-a2da-714e0920e48a",                        [{"hovertemplate":"method=hierarchical\u003cbr\u003etime=%{x}\u003cbr\u003eLoad=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hierarchical","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"hierarchical","orientation":"v","showlegend":true,"x":["2010-01-11T00:30:00","2010-01-11T01:30:00","2010-01-11T02:30:00","2010-01-11T03:30:00","2010-01-11T04:30:00","2010-01-11T05:30:00","2010-01-11T06:30:00","2010-01-11T07:30:00","2010-01-11T08:30:00","2010-01-11T09:30:00","2010-01-11T10:30:00","2010-01-11T11:30:00","2010-01-11T12:30:00","2010-01-11T13:30:00","2010-01-11T14:30:00","2010-01-11T15:30:00","2010-01-11T
Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="531d6ed5-aa1d-45b0-a825-5af367209456" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("531d6ed5-aa1d-45b0-a825-5af367209456")) {                    Plotly.newPlot(                        "531d6ed5-aa1d-45b0-a825-5af367209456",                        [{"hovertemplate":"Column=Load\u003cbr\u003eMethod=Original\u003cbr\u003eHour=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Load, Original","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Load, Original","showlegend":true,"x":{"dtype":"i2","bdata":"\\u002fAD9AP4A\u002fwAAAQEBAgEDAQQBBQEGAQcBCAEJAQoBCwEMAQ0BDgEPARABEQESARMBFAEVARYBFwEYARkBGgEbARwBHQEeAR8BIAEhASIBIwEkASUBJgEnASgBKQEqASsBLAEtAS4BLwEwATEBMgEzATQBNQE2ATcBOAE5AToBOwE8AT0BPgE\...\u002fgH\...\u002fAsACwQLCAsMCxALFAsYCxwLIAskCygLLAswCzQLOAs8C0ALRAtIC0wLUAtUC1gLXAtgC2QLaAtsC3ALdAt4C3wLgAuEC4gLjAuQC5QLmAucC6ALpAuoC6wLsAu0C7gLvAvAC8QLyAvMC9AL1AvYC9wL4AvkC+gL7AvwC\\"},"xaxis":"x","y":{"dtype":"f8","bdata":"LmaV49\u002fjg0DpEDgSWLaDQOAcvwFnl4NAuQ+K9z2Ug0AYm2c2qYSDQIoGKXj6gYNAwixZukeBg0ChslAhXXuDQFjsinQacoNAmgewyM9sg0BadWc3JF+DQCoUjsXrXoNAP\u002f89eH1Yg0B1o37NKFiDQPt6GSDsS4NAYEGr3aBLg0AJ05xhP0iDQNtRnKOORoNAqN6\u002fHvhFg0CBkgILoEKDQIQzU7X4QINA7LpcaX5Ag0CQCecJqj2DQJddi3G5OoNAMshdhBk6g0AKSzygrDeDQHJCMi52NoNA28k74vs1g0DfXGhTOjODQBnCIJ+2MoNAg8sZQN4xg0BTaXo\u002f5C6DQMQFoFFKK4NAL74N1uQpg0BpZi0F1CiDQAbR\u002fxc0KINArYFSWYkjg0AS91j6sCKDQBL3WPqwIoNAen5irjYig0BL\u002fWHwhSCDQOi4vx9zIINA7yyL0\u002foeg0BTEn5OZh2DQCPwLOZcHYNAvVr\u002f+Lwcg0BcR8H4vhuDQF63rdICG4NA\u002fTOD+MAag0A3+wPlZhiDQKTEru2dFINAc6JdhZQUg0ASb\u002fg4HhKDQOTOlr22EYNAqhhTVa0Rg0C23aklwhCDQFJ54Ag3D4NA7eOyG5cOg0Dtkif\u002fCQ6DQIu+cQg7DYNAJSlEG5sMg0DH57qVCgmDQJbFaS0BCYNABjErb1IGg0AI8qJlIwaDQNA7X\u002f0ZBoNAbygh\u002fRsFg0DZHxeL5QODQNmhBniHA4NATa4YZDH\u002fgkDoV3OAwP6CQIbUSKZ+\u002foJAicYkbWT9gkCGtCFaBv2CQIa0IVoG\u002fYJAxu9t+jP5gkCTfJF1nfiCQGl9gKSO9oJAZyz1hwH2gkBnLPWHAfaCQAp7fygt84JAPF5IhwfzgkDfe25XHvGCQOQuwhTV74JAUKinj0DugkCGTOjk6+2CQE1XHHOz7YJA7rPKTPnrgkBavcPtIOuCQCPI93vo6oJAjRB5Jj\u002fqgkAsPMMvcOmCQF3OAHK96IJAXc4Acr3ogkAt3RPayOeCQGm2l9nM5YJAQVjXshbigkBH6wMkVd+CQIDxDBoq3YJAUJAzqPHcgkDqOY7EgNyCQPmREQbU2IJANitHbefTgkDVNmoqoNGCQAycInYc0YJAE9+JWY\u002fQgkCqN1lZkc+CQKpovSmmzoJAWMxjKLLIgkDChNGsTMeCQMKE0axMx4JA\u002fWt55WrGgkBjcZOsTsaCQNXOMLWFwoJA ...

# %% [markdown]
# ## Which to use
#
# - **Start with `hierarchical`** (the default) or **`kmeans`** — both are fast and
#   accurate for most data.
# - Use **`kmedoids`** when representatives must be real, observed periods.
# - Use **`kmaxoids`** when the spread / extremes matter more than the average.
# - Use **`contiguous`** when periods must stay in calendar order.
#
# The companion choice — how each cluster becomes a single profile — is covered in
# [Representations](representations.ipynb).
